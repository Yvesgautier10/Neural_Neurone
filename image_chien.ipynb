# %%
import numpy as np
import pandas as pd

# %%
from matplotlib import image
import matplotlib.pyplot as plt

# %%
chien = image.imread("chien.jpg")
chien
# Out:
# array([[[187, 180, 125],
#         [187, 180, 125],
#         [187, 180, 125],
#         ...,
#         [ 90,  82,  33],
#         [ 86,  78,  29],
#         [ 83,  75,  26]],
#
#        [[187, 180, 125],
#         [187, 180, 125],
#         [187, 180, 125],
#         ...,
#         [ 90,  82,  33],
#         [ 86,  78,  29],
#         [ 83,  75,  26]],
#
#        [[187, 180, 125],
#         [187, 180, 125],
#         [187, 180, 125],
#         ...,
#         [ 90,  82,  33],
#         [ 86,  78,  29],
#         [ 83,  75,  26]],
#
#        ...,
#
#        [[235, 208, 178],
#         [236, 209, 179],
#         [236, 209, 179],
#         ...,
#         [236, 216, 192],
#         [239, 217, 196],
#         [240, 220, 196]],
#
#        [[232, 205, 175],
#         [233, 206, 176],
#         [234, 207, 177],
#         ...,
#         [241, 223, 201],
#         [237, 216, 197],
#         [230, 212, 190]],
#
#        [[236, 209, 179],
#         [237, 210, 180],
#         [238, 211, 181],
# ...

# %%
chien.shape
# Out:
# (120, 120, 3)

# %%
plt.imshow(chien)

# %%
plt.imshow(chien[:,:,0])
